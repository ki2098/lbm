# %%
from lbmpy.session import *

# %%
lbm_config = LBMConfig(stencil=Stencil.D3Q27, method=Method.CUMULANT, relaxation_rate=sp.Symbol('omega_v'), compressible=True)
lbm_polynom = create_lb_method(lbm_config=lbm_config)
lbm_polynom
# Out:
#         <table style="border:none; width: 100%">
#             <tr>
#                 <th colspan="3" style="text-align: left">
#                     Cumulant-Based Method
#                 </th>
#                 <td>Stencil: D3Q27</td>
#                 <td>Zero-Centered Storage: &#10003;</td>
#                 <td>Force Model: None</td>
#             </tr>
#         </table>
#
#         <table style="border:none; width: 100%">
#             <tr>
#                 <th colspan="3" style="text-align: left">
#                     Continuous Hydrodynamic Maxwellian Equilibrium
#                 </th>
#                 <td rowspan="2" style="width: 50%; text-align: center">
#                     $f (\rho, \left( u_{0}, \  u_{1}, \  u_{2}\right), \left( v_{0}, \  v_{1}, \  v_{2}\right))
# ...
